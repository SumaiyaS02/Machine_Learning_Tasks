# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Unemployment in India.csv")

# %%
df.head()
# Out:
#   Region\t Date\t Frequency\t Estimated Unemployment Rate (%)\t Estimated Employed\t Estimated Labour Participation Rate (%)\tArea
# 0  Andhra Pradesh\t 31-05-2019\t Monthly\t3.65\t1...
# 1  Andhra Pradesh\t 30-06-2019\t Monthly\t3.05\t1...
# 2  Andhra Pradesh\t 31-07-2019\t Monthly\t3.75\t1...
# 3  Andhra Pradesh\t 31-08-2019\t Monthly\t3.32\t1...
# 4  Andhra Pradesh\t 30-09-2019\t Monthly\t5.17\t1...

# %%
df.columns
# Out:
# Index(['Region\t Date\t Frequency\t Estimated Unemployment Rate (%)\t Estimated Employed\t Estimated Labour Participation Rate (%)\tArea'], dtype='object')

# %%
df=pd.read_csv("Unemployment in India.csv",sep='\t')
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.shape
# Out:
# (754, 7)

# %%
df.isna().sum()
# Out:
# Region                                      14
#  Date                                       14
#  Frequency                                  14
#  Estimated Unemployment Rate (%)            14
#  Estimated Employed                         14
#  Estimated Labour Participation Rate (%)    14
# Area                                        14
# dtype: int64

# %%
df1=df.copy(deep=True)

# %%
df1.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df1.isna().sum()
# Out:
# Region                                      14
#  Date                                       14
#  Frequency                                  14
#  Estimated Unemployment Rate (%)            14
#  Estimated Employed                         14
#  Estimated Labour Participation Rate (%)    14
# Area                                        14
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1["Region"]=le.fit_transform(df1["Region"])
df1.head()
# Out:
#    Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0       0   31-05-2019    Monthly                              3.65
# 1       0   30-06-2019    Monthly                              3.05
# 2       0   31-07-2019    Monthly                              3.75
# 3       0   31-08-2019    Monthly                              3.32
# 4       0   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df1.tail()
# Out:
#      Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 749      27   29-02-2020    Monthly                              7.55
# 750      27   31-03-2020    Monthly                              6.67
# 751      27   30-04-2020    Monthly                             15.63
# 752      27   31-05-2020    Monthly                             15.22
# 753      27   30-06-2020    Monthly                              9.86
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 749           10871168.0                                     44.09  Urban
# 750           10806105.0                                     43.34  Urban
# 751            9299466.0                                     41.20  Urban
# 752            9240903.0                                     40.67  Urban
# 753            9088931.0                                     37.57  Urban

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1[" Frequency"]=le.fit_transform(df1[" Frequency"])
df1.head()
# Out:
#    Region         Date   Frequency   Estimated Unemployment Rate (%)  \
# 0       0   31-05-2019           0                              3.65
# 1       0   30-06-2019           0                              3.05
# 2       0   31-07-2019           0                              3.75
# 3       0   31-08-2019           0                              3.32
# 4       0   30-09-2019           0                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
print(df1.columns)
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1["Area"]=le.fit_transform(df1["Area"])
df1.head()
# Out:
#    Region         Date   Frequency   Estimated Unemployment Rate (%)  \
# 0       0   31-05-2019           0                              3.65
# 1       0   30-06-2019           0                              3.05
# 2       0   31-07-2019           0                              3.75
# 3       0   31-08-2019           0                              3.32
# 4       0   30-09-2019           0                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)  Area
# 0           11999139.0                                     43.24     0
# 1           11755881.0                                     42.05     0
# 2           12086707.0                                     43.50     0
# 3           12285693.0                                     43.97     0
# 4           12256762.0                                     44.68     0

# %%
df1[' Date']=pd.to_datetime(df[' Date'])
# Out:
# C:\Users\DSBA\AppData\Local\Temp\ipykernel_51220\1429512348.py:1: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df1[' Date']=pd.to_datetime(df[' Date'])

# %%
df1[' Date'] = pd.to_datetime(
    df[' Date'].str.strip(),
    format='%d-%m-%Y'
)

# %%
le=LabelEncoder()
df1[" Date"]=le.fit_transform(df1[" Date"])
df1.head()
# Out:
#    Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 0       0      0           0                              3.65
# 1       0      1           0                              3.05
# 2       0      2           0                              3.75
# 3       0      3           0                              3.32
# 4       0      4           0                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)  Area
# 0           11999139.0                                     43.24     0
# 1           11755881.0                                     42.05     0
# 2           12086707.0                                     43.50     0
# 3           12285693.0                                     43.97     0
# 4           12256762.0                                     44.68     0

# %%
df1.isna().sum()
# Out:
# Region                                       0
#  Date                                        0
#  Frequency                                   0
#  Estimated Unemployment Rate (%)            14
#  Estimated Employed                         14
#  Estimated Labour Participation Rate (%)    14
# Area                                         0
# dtype: int64

# %%
df1 = df1.dropna()

# %%
df1.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns.str.strip())
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df['Date']=df['Date'].astype(str)
plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Estimated Unemployment Rate (%)'])
plt.title('Unemployment Rate Over Time')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
plt.show()
